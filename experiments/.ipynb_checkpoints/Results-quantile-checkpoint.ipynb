# %%
import os
import sys

os.environ['CUDA_VISIBLE_DEVICES'] = '2'
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

from sklearn.metrics.pairwise import pairwise_distances
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from cka import cka
from scipy import stats
from tqdm.notebook import tqdm
import seaborn as sns
# %matplotlib inline

import numpy as np
import barcodes

def h1sum(barc):
    if 1 in barc:
        return sum([x[1] - x[0] for x in barc[1]])
    else:
        return 0.0
    
    
from sklearn.manifold import TSNE

def plot_tsne(x, title=''):
    tsne = TSNE(n_components=2, random_state=0)
    T = tsne.fit_transform(x)
    plt.scatter(T[:,0], T[:,1])
    plt.title(title)
    plt.show()

# %% [markdown]
# # Evolution

# %%
embeddings = np.zeros((101, 10000, 64))
predicts = np.zeros((101, 10000))

for path in os.listdir('embeddings/cifar10_evolution/'):
    s, n = path.split('.')[0].split('_')
    x = np.load(f'embeddings/cifar10_evolution/{path}')
    if s == 'embedding':
        embeddings[int(n)] = x
    if s == 'predict':
        predicts[int(n)] = x.argmax(-1)
        
predicts_true = np.load('embeddings/cifar10_predicts/true_labels.npy')

# %%
embeddings = np.zeros((101, 10000, 512))
predicts = np.zeros((101, 10000)).astype(int)


embeddings[0] = np.load(f'../../my_MDWP/vgg_cifar10_evolution/embedding_00.npy')

predicts[0] = np.load(f'../../my_MDWP/vgg_cifar10_evolution/predict_00.npy')
for path in os.listdir('embeddings/vgg_cifar10_evolution/'):
    s, n = path.split('.')[0].split('_')
    x = np.load(f'embeddings/vgg_cifar10_evolution/{path}')
    if s == 'embedding':
        embeddings[int(n)+1] = x
    if s == 'predict':
        predicts[int(n)+1] = x
        
predicts_true = np.load('embeddings/cifar10_predicts/true_labels.npy')

# %%
np.random.seed(0)
np.random.randint(10, size=len(predicts))
np.random.seed(42)

# %%
np.random.seed(0)
idx = np.random.choice(range(10000), size=500, replace=False)
X = embeddings[:, idx]
y = predicts[:, idx]
y_true = predicts_true[idx]

# %% [markdown]
# ### Evaluation

# %%
acc = (y == y_true).mean(1)
dis = (y != y[-1]).mean(1) / (1 - 0.5*acc - 0.5*acc[-1])

np.save('results_quantile/evolution_dis.npy', dis)

# %%
sums = np.zeros((8, 8))
prods = np.zeros((8, 8))
ckas = np.ones((8, 8))

l = [0, 1, 3, 7, 13, 26, 51, 99]

for i in tqdm(range(len(l)), leave=True):
    for j in tqdm(range(i+1, len(l)), leave=False):
        x = X[l[i]]
        y = X[l[j]]
        barc = barcodes.calc_embed_dist(x, y, pdist_device = 'cuda:0', norm='quantile')
        s = h1sum(barc)

        barc = barcodes.calc_embed_dist(y, x, pdist_device = 'cuda:0', norm='quantile')
        s += h1sum(barc)

        sums[i,j] = s/2
        sums[j,i] = sums[i,j]

        ckas[i,j] = cka(x, y)
        ckas[j,i] = ckas[i,j]

np.save('results_quantile/vgg_evolution_h1sums.npy', sums)
np.save('results_quantile/vgg_evolution_ckas.npy', ckas)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=7.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=6.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=3.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…

# %%
sums = []
ckas = []
for i in tqdm(range(0, len(X)-1)):
    x = X[i]
    y = X[-1]
    barc = barcodes.calc_embed_dist(x, y, pdist_device = 'cuda:0', norm='quantile')
    s = h1sum(barc)
    
    barc = barcodes.calc_embed_dist(y, x, pdist_device = 'cuda:0', norm='quantile')
    s += h1sum(barc)
    
    sums.append(s/2)
    ckas.append(cka(x,y))

np.save('results_quantile/vgg_evolution_plot_h1sums.npy', sums)
np.save('results_quantile/vgg_evolution_plot_ckas.npy', ckas)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=99.0), HTML(value='')))

# %%
sums = []
for i in tqdm(range(1, len(X)-1)):
    x = X[i]
    y = X[-1]
    barc = barcodes.calc_embed_dist(x, y, pdist_device = 'cuda:0', norm='quantile')
    s = h1sum(barc)
    
    barc = barcodes.calc_embed_dist(y, x, pdist_device = 'cuda:0', norm='quantile')
    s += h1sum(barc)
    
    sums.append(s/2)

np.save('results_quantile/evolution_h1sums.npy', sums)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=99.0), HTML(value='')))

# %%
ckas = []
for i in tqdm(range(1, len(X)-1)):
    x = X[i]
    y = X[-1]
    s = cka(x, y)
    ckas.append(s)
np.save('results_quantile/evolution_ckas.npy', ckas)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=99.0), HTML(value='')))

# %% [markdown]
# ### Plots

# %%
for k in np.arange(0, 101, 10):
    plot_tsne(X[k], title=f'{k} epoch')

# %%
sums = np.load('results_quantile/evolution_h1sums.npy')
ckas = np.load('results_quantile/evolution_ckas.npy')

fig, ax = plt.subplots(1, 2, figsize=(16, 5))
ax[0].plot(sums, lw=2)
ax[0].set_title('h1sum')

ax[1].plot(ckas, lw=2)
ax[1].set_title('CKA')

plt.show()

# %%
sums = np.load('results_quantile/vgg_evolution_plot_h1sums.npy')
ckas = np.load('results_quantile/vgg_evolution_plot_ckas.npy')

fig, ax = plt.subplots(1, 2, figsize=(16, 5))
ax[0].plot(sums, lw=2)
ax[0].set_title('h1sum')

ax[1].plot(ckas, lw=2)
ax[1].set_title('CKA')

plt.show()

# %%
sums = np.load('results_quantile/vgg_evolution_plot_h1sums.npy')
ckas = np.load('results_quantile/vgg_evolution_plot_ckas.npy')
dis = np.load('results_quantile/vgg_evolution_dis.npy')[0:]

u = np.array(list(sums) + [0])
u = (u - u.min()) / (u.max() - u.min())

ckas = np.array(list(ckas) + [1])
v = 1 - ckas
v = (v - v.min()) / (v.max() - v.min())

w = dis
w = (w - w.min()) / (w.max() - w.min())


fig, ax = plt.subplots(1, 2, figsize=(16, 4))
ax[0].plot(u, lw=2, label='RTD')
ax[0].plot(v, lw=2, label='CKA')
ax[0].plot(w, lw=2, label='Disargreement')
ax[0].grid()
ax[0].legend()
ax[0].set_title('VGG-11')

sums = np.load('results_quantile/evolution_h1sums.npy')
ckas = np.load('results_quantile/evolution_ckas.npy')
dis = np.load('results_quantile/evolution_dis.npy')[0:]



#u = np.array(list(sums) + [0])
u = (u - u.min()) / (u.max() - u.min())

ckas = np.array(list(ckas) + [1])
v = 1 - ckas
v = (v - v.min()) / (v.max() - v.min())

w = dis
w = (w - w.min()) / (w.max() - w.min())

ax[1].plot(u, lw=2, label='RTD')
ax[1].plot(v, lw=2, label='CKA')
ax[1].plot(w, lw=2, label='Disargreement')
ax[1].grid()
ax[1].legend()
ax[1].set_title('ResNet-20')

plt.savefig('results_mean/evolution.png', dpi=500, facecolor='white')
plt.show()

# %%
len(w)
# Out:
# 101

# %%
(y[40] != y[-1]).mean()
# Out:
# 0.142

# %%
sums = np.load('results_quantile/vgg_evolution_h1sums.npy')
ckas = np.load('results_quantile/vgg_evolution_ckas.npy')

fig, ax = plt.subplots(1, 2, figsize=(24, 10))
sns.heatmap(sums, annot=True, ax=ax[0], cmap='Blues')
ax[0].set_title('h1sum')

sns.heatmap(ckas, annot=True, ax=ax[1], cmap='Blues')
ax[1].set_title('CKA')


plt.show()

# %% [markdown]
# # Ensembles

# %%
embeddings = np.zeros((8, 10000, 64))

for path in os.listdir('embeddings/cifar10_embeddings/'):
    s, n = path.split('.')[0].split('_')
    x = np.load(f'embeddings/cifar10_embeddings/{path}')
    if s == 'embedding':
        embeddings[int(n)-1] = x
    if s == 'embedding-fge':
        embeddings[int(n)-1 + 4] = x
    

predicts = np.zeros((8, 10000, 10))
for path in os.listdir('embeddings/cifar10_predicts/'):
    s, n = path.split('.')[0].split('_')
    x = np.load(f'embeddings/cifar10_predicts/{path}')
    if s == 'predict':
        predicts[int(n)-1] = x
    if s == 'predict-fge':
        predicts[int(n)-1 + 4] = x
y_true = np.load('embeddings/cifar10_predicts/true_labels.npy')
        
        
np.random.seed(0)
idx = np.random.choice(range(10000), size=1000, replace=False)
X = embeddings[:, idx]
y = predicts[:, idx].argmax(-1)
y_true = y_true[idx]

# %% [markdown]
# ### Evaluation

# %%
C = np.zeros((8, 8))
for i in tqdm(range(8)):
    for j in range(8):
        if i == j: continue
        barc = barcodes.calc_embed_dist(X[i], X[j], pdist_device = 'cuda:0', norm='quantile')
        C[i, j] = h1sum(barc)
        
C = (C + C.T) / 2
np.save('results_quantile/ensemble_h1sum.npy', C)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))

# %%
C = np.zeros((8, 8))
for i in tqdm(range(8)):
    for j in range(8):
        if i == j: continue
        C[i, j] = cka(X[i], X[j])
        
np.save('results_quantile/ensemble_cka.npy', C)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))

# %%
accs = (y == y_true.reshape(1, -1)).mean(1)
C = np.zeros((8, 8))
for i in tqdm(range(8)):
    for j in range(8):
        if i == j: continue
        C[i, j] = (y[i] != y[j]).sum()
        
np.save('results_quantile/ensemble_dis.npy', C)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))

# %% [markdown]
# ### Plots

# %%
# Out:
# array([[ True, False, False, False, False, False, False, False],
#        [False,  True, False, False, False, False, False, False],
#        [False, False,  True, False, False, False, False, False],
#        [False, False, False,  True, False, False, False, False],
#        [False, False, False, False,  True, False, False, False],
#        [False, False, False, False, False,  True, False, False],
#        [False, False, False, False, False, False,  True, False],
#        [False, False, False, False, False, False, False,  True]])

# %%
import scipy

A = np.ones((8,8), dtype='bool')
(~scipy.linalg.block_diag(A[:4,:4], A[4:,4:])) | np.eye(8, 8, dtype='bool')
# Out:
# array([[ True, False, False, False,  True,  True,  True,  True],
#        [False,  True, False, False,  True,  True,  True,  True],
#        [False, False,  True, False,  True,  True,  True,  True],
#        [False, False, False,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True, False, False, False],
#        [ True,  True,  True,  True, False,  True, False, False],
#        [ True,  True,  True,  True, False, False,  True, False],
#        [ True,  True,  True,  True, False, False, False,  True]])

# %%
C_h1 = np.load('results_quantile/ensemble_h1sum.npy')
C_cka = np.load('results_quantile/ensemble_cka.npy')
C_dis = np.load('results_quantile/ensemble_dis.npy')


A = np.ones((8,8), dtype='bool')
mask = (~scipy.linalg.block_diag(A[:4,:4], A[4:,4:]))
fig, ax = plt.subplots(2, 2, figsize=(16, 11))
sns.heatmap(C_h1, annot=True, ax=ax[0, 0], cmap='Blues', mask=mask)
ax[0, 0].set_title('h1sum')

np.fill_diagonal(C_cka, 1.)
sns.heatmap(C_cka, annot=True, ax=ax[0, 1], cmap='Blues',vmin=0.7, vmax=1, mask=mask)
ax[0, 1].set_title('CKA')

sns.heatmap(C_dis, annot=True, ax=ax[1, 0], cmap='Blues', mask=np.eye(8, 8, dtype='bool') | mask)
ax[1, 0].set_title('Disagreement')

plt.show()

# %% [markdown]
# # Layers

# %%
embeddings = {}

for path in tqdm(os.listdir('/home/nbalabin/Github/my_MDWP/cifar10_layers')):
    s, n = path.split('.')[0].split('_')
    x = np.load(f'/home/nbalabin/Github/my_MDWP/cifar10_layers/{path}')
    embeddings[int(n)] = x
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
embeddings = {}

for path in tqdm(os.listdir('/home/nbalabin/Github/my_MDWP/vgg_cifar10_layers')):
    s, n = path.split('.')[0].split('_')
    x = np.load(f'/home/nbalabin/Github/my_MDWP/vgg_cifar10_layers/{path}')
    embeddings[int(n)] = x
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))

# %%
np.random.seed(0)
idx = np.random.choice(range(10000), size=500, replace=False)
X = {k: v[idx] for k,v in embeddings.items()}

# %%
print(*((k, v.shape) for k,v in sorted(X.items())), sep='\n')
# Out:
# (1, (500, 16384))
# (2, (500, 16384))
# (3, (500, 16384))
# (4, (500, 16384))
# (5, (500, 8192))
# (6, (500, 8192))
# (7, (500, 8192))
# (8, (500, 4096))
# (9, (500, 4096))
# (10, (500, 4096))

# %% [markdown]
# ### Evaluation

# %%
sums = np.zeros((10, 10))
prods = np.zeros((10, 10))
ckas = np.ones((10, 10))

for i in tqdm(range(0, 10), leave=True):
    for j in tqdm(range(i+1, 10), leave=False):
        x = X[i+1]
        y = X[j+1]
        barc = barcodes.calc_embed_dist(x, y, pdist_device = 'cuda:0', norm='quantile')
        s = h1sum(barc)
        p = h1sum(barc)

        barc = barcodes.calc_embed_dist(y, x, pdist_device = 'cuda:0', norm='quantile')
        s += h1sum(barc)
        p *= h1sum(barc)

        sums[i,j] = s/2
        sums[j,i] = sums[i,j]
        
        prods[i,j] = s**0.5
        prods[j,i] = prods[i,j]

        ckas[i,j] = cka(x, y)
        ckas[j,i] = ckas[i,j]
        
np.save('results_quantile/resnet_layers_h1sums.npy', sums)
np.save('results_quantile/resnet_layers_ckas.npy', ckas)
np.save('results_quantile/resnet_layers_prods.npy', prods)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=9.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=7.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=6.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=3.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…

# %%
sums = np.zeros((8, 8))
prods = np.zeros((8, 8))
ckas = np.ones((8, 8))

for i in tqdm(range(0, 8), leave=True):
    for j in tqdm(range(i+1, 8), leave=False):
        x = X[i+1]
        y = X[j+1]
        barc = barcodes.calc_embed_dist(x, y, pdist_device = 'cuda:0', norm='quantile')
        s = h1sum(barc)
        p = h1sum(barc)

        barc = barcodes.calc_embed_dist(y, x, pdist_device = 'cuda:0', norm='quantile')
        s += h1sum(barc)
        p *= h1sum(barc)

        sums[i,j] = s/2
        sums[j,i] = sums[i,j]
        
        prods[i,j] = s**0.5
        prods[j,i] = prods[i,j]

        ckas[i,j] = cka(x, y)
        ckas[j,i] = ckas[i,j]
        
np.save('results_quantile/vgg_layers_h1sums.npy', sums)
np.save('results_quantile/vgg_layers_ckas.npy', ckas)
np.save('results_quantile/vgg_layers_prods.npy', prods)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=7.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=6.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=3.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…

# %% [markdown]
# ### Plots

# %%
sums = np.load('results_quantile/resnet_layers_h1sums.npy')
ckas = np.load('results_quantile/resnet_layers_ckas.npy')
prods = np.load('results_quantile/resnet_layers_prods.npy')

fig, ax = plt.subplots(2, 2, figsize=(16, 11))
sns.heatmap(sums, annot=True, ax=ax[0, 0], cmap='Blues', fmt='.1f')
ax[0, 0].set_title('h1sum')

sns.heatmap(ckas, annot=True, ax=ax[0, 1], cmap='Blues')
ax[0, 1].set_title('CKA')

#sns.heatmap(prods, annot=True, ax=ax[1, 0], cmap='Blues')
#ax[1, 0].set_title('Prods')

ax[1, 0].plot(sums[-1, :-1], lw=2, marker='*', markersize=10)
ax[1, 0].set_title('h1sum', )
ax[1, 0].grid()

ax[1, 1].plot(ckas[-1, :-1], lw=2, marker='*', markersize=10)
ax[1, 1].set_title('CKA')
ax[1, 1].grid()

plt.show()

# %%
sums = np.load('results_quantile/resnet_layers_h1sums.npy')
ckas = np.load('results_quantile/resnet_layers_ckas.npy')
prods = np.load('results_quantile/resnet_layers_prods.npy')

fig, ax = plt.subplots(2, 2, figsize=(16, 11))
sns.heatmap(sums, annot=True, ax=ax[0, 0], cmap='Blues', fmt='.1f')
ax[0, 0].set_title('h1sum')

sns.heatmap(ckas, annot=True, ax=ax[0, 1], cmap='Blues')
ax[0, 1].set_title('CKA')

#sns.heatmap(prods, annot=True, ax=ax[1, 0], cmap='Blues')
#ax[1, 0].set_title('Prods')

ax[1, 0].plot(sums.diagonal(1), lw=2, marker='*', markersize=10)
ax[1, 0].set_title('h1sum', )
ax[1, 0].grid()

ax[1, 1].plot(ckas.diagonal(1), lw=2, marker='*', markersize=10)
ax[1, 1].set_title('CKA')
ax[1, 1].grid()

plt.show()

# %%
sums = np.load('results_quantile/vgg_layers_h1sums.npy')
ckas = np.load('results_quantile/vgg_layers_ckas.npy')
prods = np.load('results_quantile/vgg_layers_prods.npy')

fig, ax = plt.subplots(2, 2, figsize=(16, 11))
sns.heatmap(sums, annot=True, ax=ax[0, 0], cmap='Blues', fmt='.1f')
ax[0, 0].set_title('h1sum')

sns.heatmap(ckas, annot=True, ax=ax[0, 1], cmap='Blues')
ax[0, 1].set_title('CKA')

#sns.heatmap(prods, annot=True, ax=ax[1, 0], cmap='Blues')
#ax[1, 0].set_title('Prods')

ax[1, 0].plot(sums[-1, :-1], lw=2, marker='*', markersize=10)
ax[1, 0].set_title('h1sum', )
ax[1, 0].grid()

ax[1, 1].plot(ckas[-1, :-1], lw=2, marker='*', markersize=10)
ax[1, 1].set_title('CKA')
ax[1, 1].grid()

plt.show()

# %%
# Out:
# array([0.16371262, 0.21423171, 0.24968583, 0.34377072, 0.51420441,
#        0.75004219, 0.91218718, 1.        ])

# %%
sums = np.load('results_quantile/layers_h1sums.npy')
ckas = np.load('results_quantile/layers_ckas.npy')

fig, ax = plt.subplots(1, 2, figsize=(16, 5))
ax[0].plot(sums, lw=2)
ax[0].set_title('h1sum')

ax[1].plot(ckas, lw=2)
ax[1].set_title('CKA')

plt.show()

# %%
fig, ax = plt.subplots(9, 2, figsize=(16, 40))
plt.subplots_adjust(hspace=0.3)

for i in tqdm(range(1, 10)):
    x = X[i]
    y = X[10]
    barc = barcodes.calc_embed_dist(x, y, pdist_device = 'cuda:0', norm='quantile')
    s = h1sum(barc)
    barc = barcodes.barc2array(barc)
    barcodes.plot_barcodes(barc, title=f'layer {i} -> {10}, h1sum: {s:.2f}', ax=ax[i-1, 0], fig=fig)
    
    barc = barcodes.calc_embed_dist(y, x, pdist_device = 'cuda:0', norm='quantile')
    s = h1sum(barc)
    barc = barcodes.barc2array(barc)
    barcodes.plot_barcodes(barc, title=f'layer {10} -> {i}, h1sum: {s:.2f}', ax=ax[i-1, 1], fig=fig)
    
plt.show()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=9.0), HTML(value='')))

# %% [markdown]
# # Barcodes vs Clusters

# %%
embeddings = np.zeros((101, 10000, 64))
predicts = np.zeros((101, 10000, 10))

for path in os.listdir('embeddings/cifar10_evolution/'):
    s, n = path.split('.')[0].split('_')
    x = np.load(f'embeddings/cifar10_evolution/{path}')
    if s == 'embedding':
        embeddings[int(n)] = x
    if s == 'predict':
        predicts[int(n)] = x
        
np.random.seed(0)
idx = np.random.choice(range(10000), size=1000, replace=False)
X = embeddings[:, idx]
y = predicts[:, idx]

# %%
i = 95
j = 100

tsne = TSNE(n_components=2, random_state=0)

fig, ax = plt.subplots(2, 2, figsize=(16, 11))

T = tsne.fit_transform(X[i])
ax[0, 0].scatter(T[:,0], T[:,1])
ax[0, 0].set_title(f'{i} epoch')

T = tsne.fit_transform(X[j])
ax[0, 1].scatter(T[:,0], T[:,1])
ax[0, 1].set_title(f'{j} epoch')


barc = barcodes.calc_embed_dist(X[i], X[j], pdist_device = 'cuda:0', norm='quantile')
s = h1sum(barc)
barc = barcodes.barc2array(barc)
barcodes.plot_barcodes(barc, title=f'epoch {i} -> {j}, h1sum: {s:.2f}', ax=ax[1, 0], fig=fig)


barc = barcodes.calc_embed_dist(X[j], X[i], pdist_device = 'cuda:0', norm='quantile')
s = h1sum(barc)
barc = barcodes.barc2array(barc)
barcodes.plot_barcodes(barc, title=f'epoch {j} -> {i}, h1sum: {s:.2f}', ax=ax[1, 1], fig=fig)

ylim = max(ax[1,0].get_ylim()[0], ax[1,1].get_ylim()[0]), max(ax[1,0].get_ylim()[1], ax[1,1].get_ylim()[1])
ax[1, 0].set_ylim(*ylim)
ax[1, 1].set_ylim(*ylim)


plt.show()

# %%
i = 50
j = 100

tsne = TSNE(n_components=2, random_state=0)

fig, ax = plt.subplots(2, 2, figsize=(16, 11))

T = tsne.fit_transform(X[i])
ax[0, 0].scatter(T[:,0], T[:,1])
ax[0, 0].set_title(f'{i} epoch')

T = tsne.fit_transform(X[j])
ax[0, 1].scatter(T[:,0], T[:,1])
ax[0, 1].set_title(f'{j} epoch')


barc = barcodes.calc_embed_dist(X[i], X[j], pdist_device = 'cuda:0', norm='quantile')
s = h1sum(barc)
barc = barcodes.barc2array(barc)
barcodes.plot_barcodes(barc, title=f'epoch {i} -> {j}, h1sum: {s:.2f}', ax=ax[1, 0], fig=fig)


barc = barcodes.calc_embed_dist(X[j], X[i], pdist_device = 'cuda:0', norm='quantile')
s = h1sum(barc)
barc = barcodes.barc2array(barc)
barcodes.plot_barcodes(barc, title=f'epoch {j} -> {i}, h1sum: {s:.2f}', ax=ax[1, 1], fig=fig)

ylim = max(ax[1,0].get_ylim()[0], ax[1,1].get_ylim()[0]), max(ax[1,0].get_ylim()[1], ax[1,1].get_ylim()[1])
ax[1, 0].set_ylim(*ylim)
ax[1, 1].set_ylim(*ylim)


plt.show()

# %%
i = 1
j = 100

tsne = TSNE(n_components=2, random_state=0)

fig, ax = plt.subplots(2, 2, figsize=(16, 11))

T = tsne.fit_transform(X[i])
ax[0, 0].scatter(T[:,0], T[:,1])
ax[0, 0].set_title(f'{i} epoch')

T = tsne.fit_transform(X[j])
ax[0, 1].scatter(T[:,0], T[:,1])
ax[0, 1].set_title(f'{j} epoch')


barc = barcodes.calc_embed_dist(X[i], X[j], pdist_device = 'cuda:0', norm='quantile')
s = h1sum(barc)
barc = barcodes.barc2array(barc)
barcodes.plot_barcodes(barc, title=f'epoch {i} -> {j}, h1sum: {s:.2f}', ax=ax[1, 0], fig=fig)


barc = barcodes.calc_embed_dist(X[j], X[i], pdist_device = 'cuda:0', norm='quantile')
s = h1sum(barc)
barc = barcodes.barc2array(barc)
barcodes.plot_barcodes(barc, title=f'epoch {j} -> {i}, h1sum: {s:.2f}', ax=ax[1, 1], fig=fig)

ylim = max(ax[1,0].get_ylim()[0], ax[1,1].get_ylim()[0]), max(ax[1,0].get_ylim()[1], ax[1,1].get_ylim()[1])
ax[1, 0].set_ylim(*ylim)
ax[1, 1].set_ylim(*ylim)


plt.show()

# %% [markdown]
# # -> Random

# %%
embeddings = np.zeros((101, 10000, 64))
predicts = np.zeros((101, 10000, 10))

for path in os.listdir('embeddings/cifar10_evolution/'):
    s, n = path.split('.')[0].split('_')
    x = np.load(f'embeddings/cifar10_evolution/{path}')
    if s == 'embedding':
        embeddings[int(n)] = x
    if s == 'predict':
        predicts[int(n)] = x
        
np.random.seed(0)
idx = np.random.choice(range(10000), size=1000, replace=False)
X = embeddings[:, idx]
y = predicts[:, idx]

# %%
i, j = 0, 100

N = 500

U = X[i][:N]
V = X[j][:N]

# %%
# %%timeit
barc = barcodes.calc_embed_dist(U, V, pdist_device = 'cuda:0', norm='quantile')
# Out:
# 483 ms ± 15.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
barc = barcodes.calc_embed_dist(V, U, pdist_device = 'cuda:0', norm='quantile')
# Out:
# 2min 47s ± 6.16 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
tsne = TSNE(n_components=2, random_state=0)

fig, ax = plt.subplots(2, 2, figsize=(16, 11))

T = tsne.fit_transform(U)
ax[0, 0].scatter(T[:,0], T[:,1])
ax[0, 0].set_title(f'{i} epoch')

T = tsne.fit_transform(V)
ax[0, 1].scatter(T[:,0], T[:,1])
ax[0, 1].set_title(f'{j} epoch')


barc = barcodes.calc_embed_dist(U, V, pdist_device = 'cuda:0', norm='quantile')
s = h1sum(barc)
barc = barcodes.barc2array(barc)
barcodes.plot_barcodes(barc, title=f'epoch {i} -> {j}, h1sum: {s:.2f}', ax=ax[1, 0], fig=fig)


barc = barcodes.calc_embed_dist(V, U, pdist_device = 'cuda:0', norm='quantile')
s = h1sum(barc)
barc = barcodes.barc2array(barc)
barcodes.plot_barcodes(barc, title=f'epoch {j} -> {i}, h1sum: {s:.2f}', ax=ax[1, 1], fig=fig)

ylim = max(ax[1,0].get_ylim()[0], ax[1,1].get_ylim()[0]), max(ax[1,0].get_ylim()[1], ax[1,1].get_ylim()[1])
ax[1, 0].set_ylim(*ylim)
ax[1, 1].set_ylim(*ylim)


plt.show()

# %% [markdown]
# # Blur

# %%
embeddings = np.zeros((61, 10000, 64))
predicts = np.zeros((61, 10000, 10))

for path in os.listdir('embeddings/cifar10_blur/'):
    s, n = path.split('.')[0].split('_')
    x = np.load(f'embeddings/cifar10_blur/{path}')
    if s == 'embedding':
        embeddings[int(n)] = x
    if s == 'predict':
        predicts[int(n)] = x
y_true = np.load('embeddings/cifar10_predicts/true_labels.npy')


sigmas = np.linspace(1e-10, 3+1e-10, int(3/0.05)+1)



np.random.seed(0)
idx = np.random.choice(range(10000), size=1000, replace=False)
X = embeddings[:, idx]
y = predicts[:, idx]
y_true = y_true[idx]

# %% [markdown]
# ### Evaluation

# %%
accs = (y.argmax(-1) == y_true).mean(1) * 100
np.save('results_quantile/blur_acc.npy', accs)
np.save('results_quantile/blur_sigmas', sigmas)

# %%
sums = []
for i in tqdm(range(1, len(X))):
    x = X[0]
    y = X[i]
    barc = barcodes.calc_embed_dist(x, y, pdist_device = 'cuda:0', norm='quantile')
    s = h1sum(barc)
    
    barc = barcodes.calc_embed_dist(y, x, pdist_device = 'cuda:0', norm='quantile')
    s += h1sum(barc)
    
    sums.append(s/2)

np.save('results_quantile/blur_h1sums.npy', sums)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=60.0), HTML(value='')))

# %%
ckas = []
for i in tqdm(range(1, len(X))):
    x = X[0]
    y = X[i]
    s = cka(x, y)
    ckas.append(s)
np.save('results_quantile/blur_ckas.npy', ckas)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=60.0), HTML(value='')))

# %% [markdown]
# ### Plots

# %% [markdown]
# ![](results/Blur_cifar10.png)

# %%
sigmas = np.load('results_quantile/blur_sigmas.npy')
accs = np.load('results_quantile/blur_acc.npy')
sums = np.load('results_quantile/blur_h1sums.npy')
ckas = np.load('results_quantile/blur_ckas.npy')

fig, ax = plt.subplots(2, 2, figsize=(16, 11))

ax[0, 0].plot(sigmas[1:], sums, lw=2)
ax[0, 0].set_ylabel('h1sum')
               
ax[0, 1].plot(sigmas[1:], ckas, lw=2)
ax[0, 1].set_ylabel('CKA')

ax[1, 0].plot(sigmas, accs, lw=2)
ax[1, 0].set_ylabel('Accuracy')

plt.show()

# %%
plt.scatter(accs[1:], ckas)

# %%
accs1 = accs
ckas1 = ckas

# %% [markdown]
# # Rotate

# %%
embeddings = np.zeros((61, 10000, 64))
predicts = np.zeros((61, 10000, 10))

for path in os.listdir('embeddings/cifar10_rotate/'):
    s, n = path.split('.')[0].split('_')
    x = np.load(f'embeddings/cifar10_rotate/{path}')
    if s == 'embedding':
        embeddings[int(n)] = x
    if s == 'predict':
        predicts[int(n)] = x
y_true = np.load('embeddings/cifar10_predicts/true_labels.npy')

degrees = np.linspace(0, 180, 61)

np.random.seed(0)
idx = np.random.choice(range(10000), size=1000, replace=False)
X = embeddings[:, idx]
y = predicts[:, idx]
y_true = y_true[idx]

# %%
accs = (y.argmax(-1) == y_true).mean(1) * 100
np.save('results_quantile/rotate_acc.npy', accs)
np.save('results_quantile/rotate_degrees', degrees)


sums = []
for i in tqdm(range(1, len(X))):
    x = X[0]
    y = X[i]
    barc = barcodes.calc_embed_dist(x, y, pdist_device = 'cuda:0', norm='quantile')
    s = h1sum(barc)
    
    barc = barcodes.calc_embed_dist(y, x, pdist_device = 'cuda:0', norm='quantile')
    s += h1sum(barc)
    
    sums.append(s/2)

np.save('results_quantile/rotate_h1sums.npy', sums)


ckas = []
for i in tqdm(range(1, len(X))):
    x = X[0]
    y = X[i]
    s = cka(x, y)
    ckas.append(s)
np.save('results_quantile/rotate_ckas.npy', ckas)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=60.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=60.0), HTML(value='')))

# %% [markdown]
# ![](results/rotate_cifar10.png)

# %%
degrees = np.load('results_quantile/rotate_degrees.npy')
accs = np.load('results_quantile/rotate_acc.npy')
sums = np.load('results_quantile/rotate_h1sums.npy')
ckas = np.load('results_quantile/rotate_ckas.npy')

fig, ax = plt.subplots(2, 2, figsize=(16, 11))

ax[0, 0].plot(degrees[1:], sums, lw=2)
ax[0, 0].set_ylabel('h1sum')
               
ax[0, 1].plot(degrees[1:], ckas, lw=2)
ax[0, 1].set_ylabel('CKA')

ax[1, 0].plot(degrees, accs, lw=2)
ax[1, 0].set_ylabel('Accuracy')

plt.show()

# %% [markdown]
# # Zoom

# %%
embeddings = np.zeros((29, 10000, 64))
predicts = np.zeros((29, 10000, 10))

for path in os.listdir('embeddings/cifar10_zoom/'):
    s, n = path.split('.')[0].split('_')
    x = np.load(f'embeddings/cifar10_zoom/{path}')
    if s == 'embedding':
        embeddings[int(n)] = x
    if s == 'predict':
        predicts[int(n)] = x
y_true = np.load('embeddings/cifar10_predicts/true_labels.npy')

sizes = np.arange(32, 3, -1)

np.random.seed(0)
idx = np.random.choice(range(10000), size=1000, replace=False)
X = embeddings[:, idx]
y = predicts[:, idx]
y_true = y_true[idx]

# %%
accs = (y.argmax(-1) == y_true).mean(1) * 100
np.save('results_quantile/zoom_acc.npy', accs)
np.save('results_quantile/zoom_sizes', sizes)


sums = []
for i in tqdm(range(1, len(X))):
    x = X[0]
    y = X[i]
    barc = barcodes.calc_embed_dist(x, y, pdist_device = 'cuda:0', norm='quantile')
    s = h1sum(barc)
    
    barc = barcodes.calc_embed_dist(y, x, pdist_device = 'cuda:0', norm='quantile')
    s += h1sum(barc)
    
    sums.append(s/2)

np.save('results_quantile/zoom_h1sums.npy', sums)


ckas = []
for i in tqdm(range(1, len(X))):
    x = X[0]
    y = X[i]
    s = cka(x, y)
    ckas.append(s)
np.save('results_quantile/zoom_ckas.npy', ckas)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=28.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=28.0), HTML(value='')))

# %%
sizes = np.load('results_quantile/zoom_sizes.npy')
accs = np.load('results_quantile/zoom_acc.npy')
sums = np.load('results_quantile/zoom_h1sums.npy')
ckas = np.load('results_quantile/zoom_ckas.npy')

fig, ax = plt.subplots(2, 2, figsize=(16, 11))

ax[0, 0].plot(sizes[1:], sums[::-1], lw=2)
ax[0, 0].set_ylabel('h1sum')
ax[0, 0].set_xticks(sizes[1:][::3])
ax[0, 0].set_xticklabels(sizes[1:][::-1][::3])
               
ax[0, 1].plot(sizes[1:], ckas[::-1], lw=2)
ax[0, 1].set_ylabel('CKA')
ax[0, 1].set_xticks(sizes[1:][::3])
ax[0, 1].set_xticklabels(sizes[1:][::-1][::3])

ax[1, 0].plot(sizes, accs[::-1], lw=2)
ax[1, 0].set_ylabel('Accuracy')
ax[1, 0].set_xticks(sizes[::4])
ax[1, 0].set_xticklabels(sizes[::-1][::4])

plt.show()

# %%
#plt.scatter(accs[1:], ckas)
#plt.show()
plt.scatter(accs[1:], -sums)

# %% [markdown]
# # Noise

# %%
embeddings = np.zeros((61, 10000, 64))
predicts = np.zeros((61, 10000, 10))

for path in os.listdir('embeddings/cifar10_noise/'):
    s, n = path.split('.')[0].split('_')
    x = np.load(f'embeddings/cifar10_noise/{path}')
    if s == 'embedding':
        embeddings[int(n)] = x
    if s == 'predict':
        predicts[int(n)] = x
Y_TRUE = np.load('embeddings/cifar10_predicts/true_labels.npy')

degrees = np.linspace(0, 1, 61)

np.random.seed(0)
idx = np.random.choice(range(10000), size=500, replace=False)
X = embeddings[:, idx]
y = predicts[:, idx]
y_true = Y_TRUE[idx]

# %%
from pathlib import Path

N_LAUNCHES = 5

save_dir = 'results_mean/noise'

np.random.seed(0)
seeds = np.random.randint(2**31, size=N_LAUNCHES+100, dtype=np.uint32)
seeds = np.random.choice(seeds, size=N_LAUNCHES, replace=False)
np.random.seed()
print(seeds)

for n_launch in range(1, N_LAUNCHES+1):
    np.random.seed(seeds[n_launch-1])
    idx = np.random.choice(range(10000), size=1000, replace=False)
    X = embeddings[:, idx]
    y = predicts[:, idx]
    y_true = Y_TRUE[idx]
    
    Path(f'{save_dir}/{n_launch}').mkdir(parents=True, exist_ok=True)
    
    accs = (y.argmax(-1) == y_true).mean(1) * 100
    np.save(f'{save_dir}/{n_launch}/noise_acc.npy', accs)
    np.save(f'{save_dir}/{n_launch}/noise_degrees', degrees)


    sums = []
    ckas = []
    for i in tqdm(range(1, len(X))):
        x = X[0]
        y = X[i]
        barc = barcodes.calc_embed_dist(x, y, pdist_device = 'cuda:0', norm='quantile')
        s = h1sum(barc)

        barc = barcodes.calc_embed_dist(y, x, pdist_device = 'cuda:0', norm='quantile')
        s += h1sum(barc)

        sums.append(s/2)
        
        s = cka(x, y)
        ckas.append(s)

    np.save(f'{save_dir}/{n_launch}/noise_h1sums.npy', sums)
    np.save(f'{save_dir}/{n_launch}/noise_ckas.npy', ckas)

    print(f'{n_launch} launch complete')
# Out:
# [1909838463 1449105480 1017555826 1110745632  454869706]
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=60.0), HTML(value='')))
# 1 launch complete
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=60.0), HTML(value='')))
# 2 launch complete
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=60.0), HTML(value='')))
# 3 launch complete
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=60.0), HTML(value='')))
# 4 launch complete
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=60.0), HTML(value='')))
# 5 launch complete

# %%
accs = (y.argmax(-1) == y_true).mean(1) * 100
np.save('results_quantile/noise_acc.npy', accs)
np.save('results_quantile/noise_degrees', degrees)


sums = []
for i in tqdm(range(1, len(X))):
    x = X[0]
    y = X[i]
    barc = barcodes.calc_embed_dist(x, y, pdist_device = 'cuda:0', norm='quantile')
    s = h1sum(barc)
    
    barc = barcodes.calc_embed_dist(y, x, pdist_device = 'cuda:0', norm='quantile')
    s += h1sum(barc)
    
    sums.append(s/2)

np.save('results_quantile/noise_h1sums.npy', sums)


ckas = []
for i in tqdm(range(1, len(X))):
    x = X[0]
    y = X[i]
    s = cka(x, y)
    ckas.append(s)
np.save('results_quantile/noise_ckas.npy', ckas)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=60.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-130-903cb0293dc1> in <module>
#       8     x = X[0]
#       9     y = X[i]
# ---> 10     barc = barcodes.calc_embed_dist(x, y, pdist_device = 'cuda:0', norm='quantile')
#      11     s = h1sum(barc)
#      12
#
# /home/nbalabin/Github/github/EmbedCompare/barcodes.py in calc_embed_dist(a, b, dim, pdist_device, verbose, norm, metric, use_max)
#     119         print('matrix prepared')
#     120
# --> 121     barc = rpp_py.run("--format lower-distance --dim %d" % dim, d_tril)
#     122
#     123     return barc
#
# /home/anaconda/lib/python3.8/site-packages/ripserplusplus/__init__.py in run(args, data)
#     139
#     140     # Running python binding
# --> 141     barcodes_dict = Ripser_plusplus_Converter(prog, arguments, file_name, file_format, matrix)
#     142     return barcodes_dict
#
# /home/anaconda/lib/python3.8/site-packages/ripserplusplus/Ripser_plusplus_Converter.py in Ripser_plusplus_Converter(prog, arguments, file_name, file_format, user_matrix)
#     151             return
#     152
# --> 153         user_matrix = (ctypes.c_float * num_entries)(*user_matrix)
#     154
#     155         prog.run_main.restype = Ripser_plusplus_result
#
# KeyboardInterrupt:

# %%
degrees = np.load('results_quantile/noise_degrees.npy')
accs = np.load('results_quantile/noise_acc.npy')
sums = np.load('results_quantile/noise_h1sums.npy')
ckas = np.load('results_quantile/noise_ckas.npy')

fig, ax = plt.subplots(2, 2, figsize=(16, 11))

ax[0, 0].plot(degrees[1:], sums, lw=2)
ax[0, 0].set_ylabel('h1sum')
               
ax[0, 1].plot(degrees[1:], ckas, lw=2)
ax[0, 1].set_ylabel('CKA')

ax[1, 0].plot(degrees, accs, lw=2)
ax[1, 0].set_ylabel('Accuracy')

plt.show()

# %%
degrees = np.load(f'{save_dir}/1/noise_degrees.npy')
accs = np.vstack([np.load(f'{save_dir}/{n_launch}/noise_acc.npy') for n_launch in range(1, 4)])
sums = np.vstack([np.load(f'{save_dir}/{n_launch}/noise_h1sums.npy') for n_launch in range(1, 4)])
ckas = np.vstack([np.load(f'{save_dir}/{n_launch}/noise_ckas.npy') for n_launch in range(1, 4)])

fig, ax = plt.subplots(2, 2, figsize=(16, 11))

m = sums.mean(0)
s = sums.std(0)
ax[0, 0].plot(degrees[1:], m, lw=2)
ax[0, 0].fill_between(degrees[1:], m-s, m+s, alpha=0.5)
ax[0, 0].set_ylabel('h1sum')
           
m = ckas.mean(0)
s = ckas.std(0)
ax[0, 1].plot(degrees[1:], ckas.mean(0), lw=2)
ax[0, 1].fill_between(degrees[1:], m-s, m+s, alpha=0.5)
ax[0, 1].set_ylabel('CKA')

m = accs.mean(0)
s = accs.std(0)
ax[1, 0].plot(degrees, accs.mean(0), lw=2)
ax[1, 0].fill_between(degrees, m-s, m+s, alpha=0.5)
ax[1, 0].set_ylabel('Accuracy')

plt.show()

# %%
#plt.scatter(accs[1:], ckas)
#plt.show()
m = ckas.mean(0).mean()
s = ckas.mean(0).std()
x = (ckas.mean(0) - m) / s
plt.scatter(accs.mean(0)[1:], x)

m = sums.mean(0).mean()
s = sums.mean(0).std()
x = -(sums.mean(0) - m) / s
plt.scatter(accs.mean(0)[1:], x)

# %% [markdown]
# # Brightness

# %%
embeddings = np.zeros((61, 10000, 64))
predicts = np.zeros((61, 10000, 10))

for path in os.listdir('embeddings/cifar10_color/bright/'):
    s, n = path.split('.')[0].split('_')
    x = np.load(f'embeddings/cifar10_color/bright/{path}')
    if s == 'embedding':
        embeddings[int(n)] = x
    if s == 'predict':
        predicts[int(n)] = x
y_true = np.load('embeddings/cifar10_predicts/true_labels.npy')


strengths = np.linspace(1, 0, 61)


np.random.seed(0)
idx = np.random.choice(range(10000), size=1000, replace=False)
X = embeddings[:, idx]
y = predicts[:, idx]
y_true = y_true[idx]

# %%
accs = (y.argmax(-1) == y_true).mean(1) * 100
np.save('results_quantile/bright_acc.npy', accs)
np.save('results_quantile/bright_strengths', strengths)


sums = []
for i in tqdm(range(1, len(X))):
    x = X[0]
    y = X[i]
    barc = barcodes.calc_embed_dist(x, y, pdist_device = 'cuda:0', norm='quantile')
    s = h1sum(barc)
    
    barc = barcodes.calc_embed_dist(y, x, pdist_device = 'cuda:0', norm='quantile')
    s += h1sum(barc)
    
    sums.append(s/2)

np.save('results_quantile/bright_h1sums.npy', sums)


ckas = []
for i in tqdm(range(1, len(X))):
    x = X[0]
    y = X[i]
    s = cka(x, y)
    ckas.append(s)
np.save('results_quantile/bright_ckas.npy', ckas)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=60.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=60.0), HTML(value='')))

# %%
strengths = np.load('results_quantile/bright_strengths.npy')
accs = np.load('results_quantile/bright_acc.npy')
sums = np.load('results_quantile/bright_h1sums.npy')
ckas = np.load('results_quantile/bright_ckas.npy')

fig, ax = plt.subplots(2, 2, figsize=(16, 11))

ax[0, 0].plot(strengths[1:], sums[::-1], lw=2)
ax[0, 0].set_ylabel('h1sum')
               
ax[0, 1].plot(strengths[1:], ckas[::-1], lw=2)
ax[0, 1].set_ylabel('CKA')

ax[1, 0].plot(strengths, accs[::-1], lw=2)
ax[1, 0].set_ylabel('Accuracy')

plt.show()

# %% [markdown]
# # Contrast

# %%
embeddings = np.zeros((61, 10000, 64))
predicts = np.zeros((61, 10000, 10))

for path in os.listdir('embeddings/cifar10_color/contrast/'):
    s, n = path.split('.')[0].split('_')
    x = np.load(f'embeddings/cifar10_color/contrast/{path}')
    if s == 'embedding':
        embeddings[int(n)] = x
    if s == 'predict':
        predicts[int(n)] = x
y_true = np.load('embeddings/cifar10_predicts/true_labels.npy')


strengths = np.linspace(1, 0, 61)



np.random.seed(0)
idx = np.random.choice(range(10000), size=1000, replace=False)
X = embeddings[:, idx]
y = predicts[:, idx]
y_true = y_true[idx]

# %%
accs = (y.argmax(-1) == y_true).mean(1) * 100
np.save('results_quantile/contrast_acc.npy', accs)
np.save('results_quantile/contrast_strengths', strengths)


sums = []
for i in tqdm(range(1, len(X))):
    x = X[0]
    y = X[i]
    barc = barcodes.calc_embed_dist(x, y, pdist_device = 'cuda:0', norm='quantile')
    s = h1sum(barc)
    
    barc = barcodes.calc_embed_dist(y, x, pdist_device = 'cuda:0', norm='quantile')
    s += h1sum(barc)
    
    sums.append(s/2)

np.save('results_quantile/contrast_h1sums.npy', sums)


ckas = []
for i in tqdm(range(1, len(X))):
    x = X[0]
    y = X[i]
    s = cka(x, y)
    ckas.append(s)
np.save('results_quantile/contrast_ckas.npy', ckas)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=60.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=60.0), HTML(value='')))

# %%
strengths = np.load('results_quantile/contrast_strengths.npy')
accs = np.load('results_quantile/contrast_acc.npy')
sums = np.load('results_quantile/contrast_h1sums.npy')
ckas = np.load('results_quantile/contrast_ckas.npy')

fig, ax = plt.subplots(2, 2, figsize=(16, 11))

ax[0, 0].plot(strengths[1:], sums[::-1], lw=2)
ax[0, 0].set_ylabel('h1sum')
               
ax[0, 1].plot(strengths[1:], ckas[::-1], lw=2)
ax[0, 1].set_ylabel('CKA')

ax[1, 0].plot(strengths, accs[::-1], lw=2)
ax[1, 0].set_ylabel('Accuracy')

plt.show()

# %% [markdown]
# # Saturation

# %%
embeddings = np.zeros((61, 10000, 64))
predicts = np.zeros((61, 10000, 10))

for path in os.listdir('embeddings/cifar10_color/saturation/'):
    s, n = path.split('.')[0].split('_')
    x = np.load(f'embeddings/cifar10_color/saturation/{path}')
    if s == 'embedding':
        embeddings[int(n)] = x
    if s == 'predict':
        predicts[int(n)] = x
y_true = np.load('embeddings/cifar10_predicts/true_labels.npy')


strengths = np.linspace(1, 0, 61)


np.random.seed(0)
idx = np.random.choice(range(10000), size=1000, replace=False)
X = embeddings[:, idx]
y = predicts[:, idx]
y_true = y_true[idx]

# %%
accs = (y.argmax(-1) == y_true).mean(1) * 100
np.save('results_quantile/saturation_acc.npy', accs)
np.save('results_quantile/saturation_strengths', strengths)


sums = []
for i in tqdm(range(1, len(X))):
    x = X[0]
    y = X[i]
    barc = barcodes.calc_embed_dist(x, y, pdist_device = 'cuda:0', norm='quantile')
    s = h1sum(barc)
    
    barc = barcodes.calc_embed_dist(y, x, pdist_device = 'cuda:0', norm='quantile')
    s += h1sum(barc)
    
    sums.append(s/2)

np.save('results_quantile/saturation_h1sums.npy', sums)


ckas = []
for i in tqdm(range(1, len(X))):
    x = X[0]
    y = X[i]
    s = cka(x, y)
    ckas.append(s)
np.save('results_quantile/saturation_ckas.npy', ckas)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=60.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=60.0), HTML(value='')))

# %%
strengths = np.load('results_quantile/saturation_strengths.npy')
accs = np.load('results_quantile/saturation_acc.npy')
sums = np.load('results_quantile/saturation_h1sums.npy')
ckas = np.load('results_quantile/saturation_ckas.npy')

fig, ax = plt.subplots(2, 2, figsize=(16, 11))

ax[0, 0].plot(strengths[1:], sums[::-1], lw=2)
ax[0, 0].set_ylabel('h1sum')
               
ax[0, 1].plot(strengths[1:], ckas[::-1], lw=2)
ax[0, 1].set_ylabel('CKA')

ax[1, 0].plot(strengths, accs[::-1], lw=2)
ax[1, 0].set_ylabel('Accuracy')

plt.show()

# %% [markdown]
# # Hue

# %%
embeddings = np.zeros((61, 10000, 64))
predicts = np.zeros((61, 10000, 10))

for path in os.listdir('embeddings/cifar10_color/hue/'):
    s, n = path.split('.')[0].split('_')
    x = np.load(f'embeddings/cifar10_color/hue/{path}')
    if s == 'embedding':
        embeddings[int(n)] = x
    if s == 'predict':
        predicts[int(n)] = x
y_true = np.load('embeddings/cifar10_predicts/true_labels.npy')


strengths = np.linspace(1, 0, 61)


np.random.seed(0)
idx = np.random.choice(range(10000), size=1000, replace=False)
X = embeddings[:, idx]
y = predicts[:, idx]
y_true = y_true[idx]

# %%
accs = (y.argmax(-1) == y_true).mean(1) * 100
np.save('results_quantile/hue_acc.npy', accs)
np.save('results_quantile/hue_strengths', strengths)


sums = []
for i in tqdm(range(0, len(X))):
    x = X[30]
    y = X[i]
    barc = barcodes.calc_embed_dist(x, y, pdist_device = 'cuda:0', norm='quantile')
    s = h1sum(barc)
    
    barc = barcodes.calc_embed_dist(y, x, pdist_device = 'cuda:0', norm='quantile')
    s += h1sum(barc)
    
    sums.append(s/2)

np.save('results_quantile/hue_h1sums.npy', sums)


ckas = []
for i in tqdm(range(0, len(X))):
    x = X[30]
    y = X[i]
    s = cka(x, y)
    ckas.append(s)
np.save('results_quantile/hue_ckas.npy', ckas)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=61.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=61.0), HTML(value='')))

# %%
strengths = np.load('results_quantile/hue_strengths.npy')
accs = np.load('results_quantile/hue_acc.npy')
sums = np.load('results_quantile/hue_h1sums.npy')
ckas = np.load('results_quantile/hue_ckas.npy')

fig, ax = plt.subplots(2, 2, figsize=(16, 11))

ax[0, 0].plot(strengths, sums, lw=2)
ax[0, 0].set_ylabel('h1sum')
               
ax[0, 1].plot(strengths, ckas, lw=2)
ax[0, 1].set_ylabel('CKA')

ax[1, 0].plot(strengths, accs, lw=2)
ax[1, 0].set_ylabel('Accuracy')

plt.show()

# %% [markdown]
# # Transfer Learning

# %%
dirs = [
    'embedding_100_100.npy',
    'embedding_100_10.npy',
    'embedding_10_100.npy',
    'embedding_10_10.npy']

embeddings = np.zeros((4, 10000, 64))
for n, path in enumerate(dirs):
    x = np.load(f'embeddings/cifar_transfer/{path}')
    embeddings[n] = x
    
np.random.seed(0)
idx = np.random.choice(range(10000), size=1000, replace=False)
X = embeddings[:, idx]

# %%
i = 0
j = 2

tsne = TSNE(n_components=2, random_state=0)

fig, ax = plt.subplots(2, 2, figsize=(16, 11))

T = tsne.fit_transform(X[i])
ax[0, 0].scatter(T[:,0], T[:,1])
ax[0, 0].set_title(f'CIFAR-100 before')

T = tsne.fit_transform(X[j])
ax[0, 1].scatter(T[:,0], T[:,1])
ax[0, 1].set_title(f'CIFAR-100 after')


barc = barcodes.calc_embed_dist(X[i], X[j], pdist_device = 'cuda:0', norm='quantile')
s = h1sum(barc)
barc = barcodes.barc2array(barc)
barcodes.plot_barcodes(barc, title=f'before -> after, h1sum: {s:.2f}', ax=ax[1, 0], fig=fig)


barc = barcodes.calc_embed_dist(X[j], X[i], pdist_device = 'cuda:0', norm='quantile')
s = h1sum(barc)
barc = barcodes.barc2array(barc)
barcodes.plot_barcodes(barc, title=f'after -> before, h1sum: {s:.2f}', ax=ax[1, 1], fig=fig)

ylim = max(ax[1,0].get_ylim()[0], ax[1,1].get_ylim()[0]), max(ax[1,0].get_ylim()[1], ax[1,1].get_ylim()[1])
ax[1, 0].set_ylim(*ylim)
ax[1, 1].set_ylim(*ylim)


plt.show()

# %%
i = 1
j = 3

tsne = TSNE(n_components=2, random_state=0)

fig, ax = plt.subplots(2, 2, figsize=(16, 11))

T = tsne.fit_transform(X[i])
ax[0, 0].scatter(T[:,0], T[:,1])
ax[0, 0].set_title(f'CIFAR-10 before')

T = tsne.fit_transform(X[j])
ax[0, 1].scatter(T[:,0], T[:,1])
ax[0, 1].set_title(f'CIFAR-10 after')


barc = barcodes.calc_embed_dist(X[i], X[j], pdist_device = 'cuda:0', norm='quantile')
s = h1sum(barc)
barc = barcodes.barc2array(barc)
barcodes.plot_barcodes(barc, title=f'before -> after, h1sum: {s:.2f}', ax=ax[1, 0], fig=fig)


barc = barcodes.calc_embed_dist(X[j], X[i], pdist_device = 'cuda:0', norm='quantile')
s = h1sum(barc)
barc = barcodes.barc2array(barc)
barcodes.plot_barcodes(barc, title=f'after -> before, h1sum: {s:.2f}', ax=ax[1, 1], fig=fig)

ylim = max(ax[1,0].get_ylim()[0], ax[1,1].get_ylim()[0]), max(ax[1,0].get_ylim()[1], ax[1,1].get_ylim()[1])
ax[1, 0].set_ylim(*ylim)
ax[1, 1].set_ylim(*ylim)


plt.show()

# %% [markdown]
# # Minimize CKA

# %%
embeddings = np.zeros((3, 10000, 64))
predicts = np.zeros((3, 10000, 10))

for path in os.listdir('embeddings/cifar10_minimize_cka/'):
    s, n = path.split('.')[0].split('_')
    x = np.load(f'embeddings/cifar10_minimize_cka/{path}')
    if s == 'embedding':
        embeddings[int(n)-1] = x
    if s == 'predict':
        predicts[int(n)-1] = x
        
y_true = np.load('embeddings/cifar10_predicts/true_labels.npy')
        
np.random.seed(0)
idx = np.random.choice(range(10000), size=1000, replace=False)
X = embeddings[:, idx]
y = predicts[:, idx].argmax(-1)
y_true = y_true[idx]

# %%
print(f'accuracy: {(y_true == y).mean(1)}')
# Out:
# accuracy: [0.913 0.916 0.912]

# %%
(y.reshape(1,3, 1000) == y.reshape(3, 1, 1000)).mean(-1)
# Out:
# array([[1.   , 0.921, 0.916],
#        [0.921, 1.   , 0.959],
#        [0.916, 0.959, 1.   ]])

# %%
# !ls embeddings/cifar10_minimize_cka/
# Out:
# embedding_1.npy  embedding_3.npy  predict_2.npy
# embedding_2.npy  predict_1.npy	  predict_3.npy

# %% [markdown]
# ### Plots

# %%
i = 0
j = 1

tsne = TSNE(n_components=2, random_state=0)

fig, ax = plt.subplots(2, 2, figsize=(16, 11))

T = tsne.fit_transform(X[i])
ax[0, 0].scatter(T[:,0], T[:,1], c=y_true)
ax[0, 0].set_title(f'model 1')

T = tsne.fit_transform(X[j])
ax[0, 1].scatter(T[:,0], T[:,1], c=y_true)
ax[0, 1].set_title(f'model 2')


barc = barcodes.calc_embed_dist(X[i], X[j], pdist_device = 'cuda:0', norm='quantile')
s = h1sum(barc)
barc = barcodes.barc2array(barc)
barcodes.plot_barcodes(barc, title=f'1 -> 2, h1sum: {s:.2f}', ax=ax[1, 0], fig=fig)


barc = barcodes.calc_embed_dist(X[j], X[i], pdist_device = 'cuda:0', norm='quantile')
s = h1sum(barc)
barc = barcodes.barc2array(barc)
barcodes.plot_barcodes(barc, title=f'2 -> 1, h1sum: {s:.2f}', ax=ax[1, 1], fig=fig)

ylim = max(ax[1,0].get_ylim()[0], ax[1,1].get_ylim()[0]), max(ax[1,0].get_ylim()[1], ax[1,1].get_ylim()[1])
ax[1, 0].set_ylim(*ylim)
ax[1, 1].set_ylim(*ylim)

plt.show()

print(f'CKA: {cka(X[i], X[j]):.2f}')
# Out:
# CKA: 0.90

# %%
i = 0
j = 2

tsne = TSNE(n_components=2, random_state=0)

fig, ax = plt.subplots(2, 2, figsize=(16, 11))

T = tsne.fit_transform(X[i])
ax[0, 0].scatter(T[:,0], T[:,1], c=y_true)
ax[0, 0].set_title(f'model 1')

T = tsne.fit_transform(X[j])
ax[0, 1].scatter(T[:,0], T[:,1], c=y_true)
ax[0, 1].set_title(f'model 2 (changed)')


barc = barcodes.calc_embed_dist(X[i], X[j], pdist_device = 'cuda:0', norm='quantile')
s = h1sum(barc)
barc = barcodes.barc2array(barc)
barcodes.plot_barcodes(barc, title=f'1 -> 2 (changed), h1sum: {s:.2f}', ax=ax[1, 0], fig=fig)


barc = barcodes.calc_embed_dist(X[j], X[i], pdist_device = 'cuda:0', norm='quantile')
s = h1sum(barc)
barc = barcodes.barc2array(barc)
barcodes.plot_barcodes(barc, title=f'2 (changed) -> 1, h1sum: {s:.2f}', ax=ax[1, 1], fig=fig)

ylim = max(ax[1,0].get_ylim()[0], ax[1,1].get_ylim()[0]), max(ax[1,0].get_ylim()[1], ax[1,1].get_ylim()[1])
ax[1, 0].set_ylim(*ylim)
ax[1, 1].set_ylim(*ylim)

plt.show()

print(f'CKA: {cka(X[i], X[j]):.2f}')
# Out:
# CKA: 0.06
